# %%
import pandas as pd
dataset1 = pd.read_excel('./mushrooms.xlsx',dtype=str)
dataset1.head(5)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
from id3 import Id3Estimator, export_graphviz, export_text
import pydot
import numpy as np

feature_names = ["cap-shape","cap-surface","cap-color",
                 "bruises","odor","gill-attachment",
                 "gill-spacing","gill-size","gill-color",
                 "stalk-shape","stalk-root","stalk-surface-above-ring",
                 "stalk-surface-below-ring","stalk-color-above-ring","stalk-color-below-ring",
                 "veil-type","veil-color","ring-number",
                 "ring-type","spore-print-color","population",
                 "habitat"]

X = dataset1.drop(['class'], axis=1).to_numpy().astype('S32')

y = dataset1['class'].to_numpy().astype('S32')

clf = Id3Estimator(prune=False)
clf.fit(X, y, check_input=True)

export_graphviz(clf.tree_, "out.dot", feature_names)
# Out:
# <_io.TextIOWrapper name='out.dot' mode='w' encoding='utf8'>

# %%
[graph,]= pydot.graph_from_dot_file('out.dot')
#graph.write_png('out.png')
pic = graphviz.Source(graph)
pic

# %%
print(export_text(clf.tree_, feature_names))
# Out:
# odor a: e (400)
# odor c: p (192)
# odor f: p (2160)
# odor l: e (400)
# odor m: p (36)
# odor n
# |   spore-print-color b: e (48)
# |   spore-print-color h: e (48)
# |   spore-print-color k: e (1296)
# |   spore-print-color n: e (1344)
# |   spore-print-color o: e (48)
# |   spore-print-color r: p (72)
# |   spore-print-color u: e (3408/120)
# |   spore-print-color w
# |   |   habitat d
# |   |   |   gill-size b: e (8)
# |   |   |   gill-size n: p (32)
# |   |   habitat g: e (288)
# |   |   habitat l
# |   |   |   cap-color b: e (48/16)
# |   |   |   cap-color c: e (24)
# |   |   |   cap-color e: e (48/16)
# |   |   |   cap-color g: e (48/16)
# |   |   |   cap-color n: e (24)
# |   |   |   cap-color p: e (48/16)
# |   |   |   cap-color r: e (48/16)
# |   |   |   cap-color u: e (48/16)
# |   |   |   cap-color w: p (8)
# |   |   |   cap-color y: p (8)
# |   |   habitat m: e (576/48)
# |   |   habitat p: e (40)
# |   |   habitat u: e (576/48)
# |   |   habitat w: e (192)
# |   spore-print-color y: e (48)
# odor p: p (256)
# odor s: p (576)
# odor y: p (576)

# %%
predict1 = dataset1.drop(['class'], axis=1).to_numpy().astype('S32')[0:5]

# %%
result = clf.predict(predict1)
result
# Out:
# C:\Users\seerowdom\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array([b'p', b'e', b'e', b'p', b'e'], dtype='|S32')

# %%
dataset1.head(5)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
label = y[0:5]
check = label == result

# %%
# Out:
# array([ True,  True,  True,  True,  True])

# %%
result[0].decode('UTF-8')
# Out:
# 'p'

# %%
from sklearn.model_selection import cross_val_score, train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
X_train
# Out:
# array([[b'k', b's', b'e', ..., b'w', b'v', b'p'],
#        [b'x', b'f', b'g', ..., b'h', b'v', b'g'],
#        [b'f', b'y', b'g', ..., b'h', b'v', b'p'],
#        ...,
#        [b'f', b's', b'e', ..., b'w', b'v', b'd'],
#        [b'x', b'y', b'n', ..., b'k', b'y', b'd'],
#        [b'f', b'y', b'e', ..., b'w', b'c', b'd']], dtype='|S32')
